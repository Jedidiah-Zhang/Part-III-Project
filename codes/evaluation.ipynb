# %%
from functions import *

# %%
time_frame, target, output = testLocalized()

# %%
plt.plot(output[time_frame], label='Predicted')
plt.plot(target[time_frame], label='Target')
plt.xlabel('time frames')
plt.ylabel('travel_time')
time_frame += 1

# %%
_, targets, outputs = testLocalized(mode=0, start_frame=2800)
plt.plot(targets, label='Target')
plt.plot(outputs, label='Predicted')
plt.xlabel('time frames')
plt.ylabel('travel_time')
plt.legend()
plt.show()

# %%
_, targets, outputs = testLocalized(mode=0, start_frame=0, length=-1)
plt.plot(targets, label='Target')
plt.plot(outputs, label='Predicted')
plt.xlabel('time frames')
plt.ylabel('travel_time')
plt.legend(loc="upper center")
plt.show()

# %% [markdown]
# ## Globalized

# %%
time_frame, targets, outputs = testGlobalized(mode=1, link=131, start_frame=0)

# %%
time_frame = 0

# %%
plt.plot(outputs[time_frame], label='Predicted')
plt.plot(targets[time_frame], label='Target')
plt.xlabel('time frames')
plt.ylabel('travel_time')
time_frame += 1

# %%
_, targets, outputs = testGlobalized(mode=0, link=2, start_frame=0, length=1440)
plt.plot(targets, label='Target')
plt.plot(outputs, label='Predicted')
plt.xlabel('time frames')
plt.ylabel('travel_time')
plt.legend(loc="upper center")
plt.show()
